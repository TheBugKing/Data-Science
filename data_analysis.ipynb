# %%
import pandas as pd
import numpy as np
import os

# %%
data_path = os.path.join(os.getcwd(),'dataset\\KPMG_VI_New_raw_data_update_final.xlsx')
data_path
# Out:
# 'd:\\Project\\python Basic\\KPMG\\dataset\\KPMG_VI_New_raw_data_update_final.xlsx'

# %%
CustomerDemographic = pd.read_excel(data_path, sheet_name="CustomerDemographic",parse_dates=True, skiprows=[0])
# Out:
# C:\Users\Voltage\AppData\Local\Temp/ipykernel_12060/1650659374.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   CustomerDemographic = pd.read_excel(data_path, sheet_name="CustomerDemographic",parse_dates=True, skiprows=[0])

# %%
CustomerDemographic.head(3)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            2        Eli    Bockman   Male
# 2            3      Arlin     Dearle   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
# 2              Property  Mass Customer                  N
#
#                         default owns_car  tenure
# 0                            "'      Yes    11.0
# 1  <script>alert('hi')</script>      Yes    16.0
# 2           2018-02-01 00:00:00      Yes    15.0

# %%
CustomerDemographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
CustomerDemographic.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
CustomerDemographic.corr()
# Out:
#                                      customer_id  \
# customer_id                             1.000000
# past_3_years_bike_related_purchases    -0.002529
# tenure                                 -0.019947
#
#                                      past_3_years_bike_related_purchases  \
# customer_id                                                    -0.002529
# past_3_years_bike_related_purchases                             1.000000
# tenure                                                         -0.009508
#
#                                        tenure
# customer_id                         -0.019947
# past_3_years_bike_related_purchases -0.009508
# tenure                               1.000000

# %%
CustomerDemographic.drop(["default"], axis=1, inplace=True)

# %%
path= f'dataset\\CustomerDemographic\\ValueCounts.xlsx'
dpath="dataset\\CustomerDemographic"
def writeValueCountsToExcel(path,dpath,columns):
    fpath= os.path.join(os.getcwd(),path)
    writer = pd.ExcelWriter(fpath)
    def getValueCounts(path,columns):
        for i,col in enumerate(columns):
            index = CustomerDemographic[col].value_counts(dropna=False).index.tolist()
            value = CustomerDemographic[col].value_counts(dropna=False).values
            df = pd.DataFrame({col: index, 'counts':value})
            if not os.path.exists(os.path.join(os.getcwd(),dpath)):
                os.makedirs(os.path.join(os.getcwd(),dpath))
            if len(col) > 31:
                col=col[:31]
            df.to_excel(writer,col,index=True)
    getValueCounts(fpath,CustomerDemographic.columns)
    writer.save()

# %%
from datetime import datetime
index = CustomerDemographic["DOB"].value_counts(dropna=False).index.tolist()
value = CustomerDemographic["DOB"].value_counts(dropna=False).values
df = pd.DataFrame({"DOB": index, 'counts':value})
if ("1843-12-21 00:00:00") in df["DOB"].values.tolist():
    print("here")

# %%
index = CustomerDemographic["DOB"].value_counts(dropna=False).index.tolist()
for t in index:
    print(type(t))
# Out:
# <class 'pandas._libs.tslibs.nattype.NaTType'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ...
